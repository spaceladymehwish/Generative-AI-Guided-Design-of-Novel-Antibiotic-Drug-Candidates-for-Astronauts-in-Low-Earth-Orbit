# %% [markdown]
# ## **Importing Libraries**

# %%
# %%capture
# !pip install mordred
# !pip install rdkit

# %%
# Importing Libraries
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw, PandasTools, AllChem

import mordred
from mordred import Calculator, descriptors

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

pd.set_option('display.max_columns', 2000)
warnings.filterwarnings("ignore")

# %%
sns.set(style='whitegrid')

# %%
df = pd.read_csv('4-3D descriptors RDKIT.csv')

# %% [markdown]
# ## **Data Preprocessing**
#
#
#
# 1.   Removing missing values/non-numerical values
# 2.   Remove constant values
# 3.   Remove highly correlated values

# %%
# Drop duplicated rows
df1 = df.drop_duplicates()

# %%
df1.shape
# Out:
# (17597, 12)

# %%
df1.head()
# Out:
#    values         PMI1          PMI2          PMI3      NPR1      NPR2  \
# 0       1   135.513538    255.808138    322.030592  0.420810  0.794360
# 1       1  1012.625649   3430.880212   4079.681989  0.248212  0.840968
# 2       1  7289.793059  10527.183650  14056.605320  0.518603  0.748914
# 3       1  1465.559555   6004.298168   7318.618475  0.200251  0.820414
# 4       1  1966.818432   9982.980466  11066.415020  0.177729  0.902097
#
#    RadiusOfGyration  InertialShapeFactor  Eccentricity  Asphericity  \
# 0          1.682460             0.005862      0.907149     0.210838
# 1          3.723104             0.000830      0.968706     0.431572
# 2          4.659840             0.000103      0.855015     0.135300
# 3          4.357687             0.000560      0.979745     0.517477
# 4          4.814120             0.000459      0.984080     0.559647
#
#    SpherocityIndex       PBF
# 0         0.199398  0.395514
# 1         0.208437  0.833922
# 2         0.434389  1.641599
# 3         0.068108  0.510451
# 4         0.161120  0.954113

# %%
df1.isnull().sum().sum()

# %%
column_num = []
column_bool = []
for column in df1.columns:
  column_type = df1[column].dtype
  if column_type == 'object':
      pass
  elif column_type =='bool':
      column_bool.append(column)
  else:
      column_num.append(column)

# %%
len(column_num)

# %%
column_bool

# %%
# To calclulate  Correlation and remove highly  correlated columns
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
# Dropping highly correlated Features
corr_features = correlation(df1, 0.80)
print("No. of features to drop : ",len(set(corr_features)))

df1.drop(corr_features,axis=1,inplace=True)

# %%
df1.shape

# %%
df1.head()
# Out:
#    values         PMI1          PMI2      NPR1      NPR2  RadiusOfGyration  \
# 0       1   135.513538    255.808138  0.420810  0.794360          1.682460
# 1       1  1012.625649   3430.880212  0.248212  0.840968          3.723104
# 2       1  7289.793059  10527.183650  0.518603  0.748914          4.659840
# 3       1  1465.559555   6004.298168  0.200251  0.820414          4.357687
# 4       1  1966.818432   9982.980466  0.177729  0.902097          4.814120
#
#    InertialShapeFactor  SpherocityIndex       PBF
# 0             0.005862         0.199398  0.395514
# 1             0.000830         0.208437  0.833922
# 2             0.000103         0.434389  1.641599
# 3             0.000560         0.068108  0.510451
# 4             0.000459         0.161120  0.954113

# %%
df1.to_csv('RDKit_3D_truncated.csv', index=None)

# %%
df1['values'].info()

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x=df1["values"], palette="coolwarm")  # Replace "target" with actual column name
plt.title("Class Distribution")
plt.xlabel("Class (0 or 1)")
plt.ylabel("Count")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaled_DF = pd.DataFrame(StandardScaler().fit_transform(df1.iloc[:,1:]), columns=df1.iloc[:,1:].columns)

# %%
scaled_DF.head()
# Out:
#        PMI1      PMI2      NPR1      NPR2  RadiusOfGyration  \
# 0 -0.394453 -0.253658  1.343690 -0.597623         -1.924884
# 1 -0.245471 -0.171661  0.050300 -0.142374         -0.548211
# 2  0.820737  0.011602  2.076520 -1.041524          0.083736
# 3 -0.168538 -0.105202 -0.309104 -0.343132         -0.120105
# 4 -0.083397 -0.002452 -0.477879  0.454718          0.187818
#
#    InertialShapeFactor  SpherocityIndex       PBF
# 0             0.524304         0.162323 -1.331211
# 1            -0.043531         0.238432 -0.064677
# 2            -0.125664         2.140936  2.268654
# 3            -0.074081        -0.943124 -0.999163
# 4            -0.085495        -0.159973  0.282549

# %%
y = df1['values']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: values, dtype: int64

# %%
y.shape

# %%
scaled_DF.shape

# %% [markdown]
# # **SMOTE**

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE
# Apply SMOTE to balance the entire dataset, increasing minority class instances
smote = SMOTE(sampling_strategy={0: 11000, 1: 11000}, random_state=42)

# Now use the imputed data for SMOTE
X_resampled, y_resampled = smote.fit_resample(scaled_DF, y)

# %%
scaler = StandardScaler()
X_resampled_scaled = pd.DataFrame(scaler.fit_transform(X_resampled), columns = X_resampled.columns)

# %%
# Combine scaled features and target variable
final_df = pd.concat([X_resampled_scaled, y_resampled], axis=1)

# Save the DataFrame to a CSV file
final_df.to_csv('RDKit3D_scaled_data.csv', index=False)

# %%
X_resampled_scaled.head()
# Out:
#        PMI1      PMI2      NPR1      NPR2  RadiusOfGyration  \
# 0 -0.416267 -0.260116  1.345511 -0.602951         -1.931896
# 1 -0.256620 -0.175355  0.052397 -0.147606         -0.548179
# 2  0.885918  0.014085  2.078184 -1.046947          0.087002
# 3 -0.174179 -0.106656 -0.306930 -0.348407         -0.117882
# 4 -0.082943 -0.000443 -0.475669  0.449613          0.191616
#
#    InertialShapeFactor  SpherocityIndex       PBF
# 0             0.585006         0.157481 -1.340883
# 1            -0.046893         0.233452 -0.067527
# 2            -0.138292         2.132503  2.278375
# 3            -0.080889        -0.945960 -1.007047
# 4            -0.093591        -0.164230  0.281570

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count each class and store in a variable
class_counts = final_df['values'].value_counts()

# Print the class counts
print(class_counts)

# Create a countplot
plt.figure(figsize=(5, 4))
sns.countplot(x=final_df["values"], palette="coolwarm")
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
y = final_df['values']

# %%
y.shape
# Out:
# (22000,)

# %%
X = final_df.drop('values', axis=1)

# %%
X.shape
# Out:
# (22000, 8)

# %%
X.head()
# Out:
#        PMI1      PMI2      NPR1      NPR2  RadiusOfGyration  \
# 0 -0.416267 -0.260116  1.345511 -0.602951         -1.931896
# 1 -0.256620 -0.175355  0.052397 -0.147606         -0.548179
# 2  0.885918  0.014085  2.078184 -1.046947          0.087002
# 3 -0.174179 -0.106656 -0.306930 -0.348407         -0.117882
# 4 -0.082943 -0.000443 -0.475669  0.449613          0.191616
#
#    InertialShapeFactor  SpherocityIndex       PBF
# 0             0.585006         0.157481 -1.340883
# 1            -0.046893         0.233452 -0.067527
# 2            -0.138292         2.132503  2.278375
# 3            -0.080889        -0.945960 -1.007047
# 4            -0.093591        -0.164230  0.281570
